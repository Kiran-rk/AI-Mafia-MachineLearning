# %%
import cv2
import numpy as np
import pandas as pd

# %%
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
eyes_cascade=cv2.CascadeClassifier("frontalEyes35x16.xml")
nose_cascade = cv2.CascadeClassifier("Nose18x15.xml")
img = cv2.imread('Before.png')
mustache = cv2.imread('mustache.png',-1)
glasses = cv2.imread('glasses.png',-1)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = cv2.cvtColor(img, cv2.COLOR_BGR2BGRA)#make picture gray

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eyes_cascade.detectMultiScale(roi_gray,1.3,5)
    for(ex,ey,ew,eh) in eyes:
        roi_eyes = roi_gray[ey:ey+eh, ex:ex+w]
        glasses2 = cv2.resize(glasses.copy(),(int(1*ew),int(2.63*eh)))
        print(glasses2.shape)
        gw, gh, gc = glasses2.shape
        for i in range(0,gw):
            for j in range(0,gh):
                if glasses2[i,j][3] != 0:
                    roi_color[ ey - int(eh/1.5)+i, int(ex)+j] = glasses2[i, j]




    nose = nose_cascade.detectMultiScale(roi_gray, 1.3, 5)
    for (nx, ny, nw, nh) in nose:
        roi_nose = roi_gray[ny: ny+nh, nx:nx+nw]
        mustache2 = cv2.resize(mustache.copy(),(int(1.2*nw),int(0.4*ny)))
        print(glasses2.shape)
        mw, mh, mc = mustache2.shape
        for i in range(0,mw):
            for j in range(0,mh):
                if mustache2[i,j][3] != 0:
                    roi_color[ny + int(nh/1.5) + i, nx+j] = mustache2[i,j]
# Out:
# (202, 169, 4)
# (202, 169, 4)

# %%
glasses.shape
# Out:
# (221, 483, 4)

# %%
dfa = pd.DataFrame({"Prediction (R, G , B)" : list(img)})

# %%
dfa
# Out:
#                                  Prediction (R, G , B)
# 0    [[180, 202, 219, 255], [181, 203, 220, 255], [...
# 1    [[180, 202, 219, 255], [181, 203, 220, 255], [...
# 2    [[180, 202, 219, 255], [181, 203, 220, 255], [...
# 3    [[180, 202, 219, 255], [180, 202, 219, 255], [...
# 4    [[181, 203, 220, 255], [180, 202, 219, 255], [...
# ..                                                 ...
# 480  [[0, 0, 4, 255], [0, 1, 5, 255], [2, 3, 7, 255...
# 481  [[1, 1, 6, 255], [0, 1, 5, 255], [2, 3, 7, 255...
# 482  [[1, 2, 6, 255], [0, 1, 5, 255], [1, 2, 6, 255...
# 483  [[2, 3, 7, 255], [1, 2, 6, 255], [0, 1, 5, 255...
# 484  [[2, 3, 7, 255], [0, 1, 5, 255], [0, 1, 5, 255...
#
# [485 rows x 1 columns]

# %%
img.shape
# Out:
# (485, 377, 4)

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Before.png')
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)  
plt.imshow(img)
plt.show()
plt.imshow(img1)
plt.show()
img.shape
# Out:
# (485, 377, 3)

# %%
coloured = cv2.cvtColor(img, cv2.COLOR_RGBA2BGRA)
plt.imshow(coloured)

# %%
image = cv2.imread("Jamie_Before.jpg", -1)
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
