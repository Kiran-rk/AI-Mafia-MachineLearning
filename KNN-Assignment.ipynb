# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
df=pd.read_csv('Diabetes_XTrain.csv')
df.plot.bar()
plt.show()

# %%
plt.hist(x['Pregnancies'],rwidth=0.8)
plt.show()

# %%
plt.hist(x['Glucose'],rwidth=0.8,color='orange')
plt.show()

# %%
plt.hist(x['BloodPressure'],rwidth=0.8,color='green')
plt.show()

# %%
plt.hist(x['SkinThickness'],rwidth=0.8,color='red')
plt.show()

# %%
plt.hist(x['Insulin'],rwidth=0.8,color='purple')
plt.show()

# %%
plt.hist(x['BMI'],rwidth=0.8,color='brown')
plt.show()

# %%
plt.hist(x['DiabetesPedigreeFunction'],rwidth=0.8,color='pink')
plt.show()

# %%
plt.hist(x['Age'],rwidth=0.8,color='grey')
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            7      168             88             42      321  38.2
# 1            8      110             76              0        0  27.8
# 2            7      147             76              0        0  39.4
# 3            2      100             66             20       90  32.9
# 4            4      129             86             20      270  35.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.787   40
# 1                     0.237   58
# 2                     0.257   43
# 3                     0.867   28
# 4                     0.231   23

# %%
non_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
for coloumn in non_zero:
    df[coloumn] = df[coloumn].replace(0,np.NaN)
    mean = int(df[coloumn].mean(skipna = True))
    df[coloumn] = df[coloumn].replace(np.NaN, mean)
    print(df[coloumn])
# Out:
# 0      168.0
# 1      110.0
# 2      147.0
# 3      100.0
# 4      129.0
#        ...
# 571    111.0
# 572    187.0
# 573    122.0
# 574    154.0
# 575     88.0
# Name: Glucose, Length: 576, dtype: float64
# 0      88.0
# 1      76.0
# 2      76.0
# 3      66.0
# 4      86.0
#        ...
# 571    60.0
# 572    68.0
# 573    60.0
# 574    72.0
# 575    78.0
# Name: BloodPressure, Length: 576, dtype: float64
# 0      42.0
# 1      28.0
# 2      28.0
# 3      20.0
# 4      20.0
#        ...
# 571    28.0
# 572    39.0
# 573    18.0
# 574    29.0
# 575    29.0
# Name: SkinThickness, Length: 576, dtype: float64
# 0      321.0
# 1      147.0
# 2      147.0
# 3       90.0
# 4      270.0
#        ...
# 571    147.0
# 572    304.0
# 573    106.0
# 574    126.0
# 575     76.0
# Name: Insulin, Length: 576, dtype: float64
# 0      38.2
# 1      27.8
# 2      39.4
# 3      32.9
# 4      35.1
#        ...
# 571    26.2
# 572    37.7
# 573    29.8
# 574    31.3
# 575    32.0
# ...

# %%
def distance(v1,v2):
    return(np.sqrt(sum((v1-v2)**2)))
